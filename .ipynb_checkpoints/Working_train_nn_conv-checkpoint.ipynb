# %%
import pandas as pd
import numpy as np
import torch
from sklearn import preprocessing
dtype = torch.float64
device = torch.device("cuda:0")
torch.manual_seed(42)
data = pd.read_csv("NN_training.nn")
np.random.seed(42)

# %%
data = data.set_index("Unnamed: 0")

# %%
data.iloc[0,0]
# Out:
# 24.0

# %%
data.head()
# Out:
#             Actual Velocity       0_x      10_x      20_x      30_x      40_x  \
# Unnamed: 0
# 0                      24.0  0.002890  0.002176  0.004270  0.007065  0.009169
# 1                      24.0  0.002890  0.002176  0.004270  0.007065  0.009169
# 2                      25.0  0.006483  0.012145  0.016721  0.014323  0.019283
# 3                      25.0  0.006483  0.012145  0.016721  0.014323  0.019283
# 4                      25.0  0.006483  0.012145  0.016721  0.014323  0.019283
#
#                 50_x      60_x      70_x      80_x  ...    2500_y    2510_y  \
# Unnamed: 0                                          ...
# 0           0.008229  0.006080  0.010589  0.017297  ...  0.001342  0.001679
# 1           0.008229  0.006080  0.010589  0.017297  ...  0.001342  0.001679
# 2           0.015196  0.018086  0.011794  0.021855  ...  0.001500  0.001161
# 3           0.015196  0.018086  0.011794  0.021855  ...  0.001500  0.001161
# 4           0.015196  0.018086  0.011794  0.021855  ...  0.001500  0.001161
#
#               2520_y    2530_y    2540_y    2550_y  mean_acc_y  median_y  \
# Unnamed: 0
# 0           0.001001  0.001741  0.001173  0.001034    0.441387  0.353673
# 1           0.001001  0.001741  0.001173  0.001034    0.441387  0.353673
# 2           0.001255  0.001117  0.000859  0.001176    0.435271  0.328850
# 3           0.001255  0.001117  0.000859  0.001176    0.435271  0.328850
# 4           0.001255  0.001117  0.000859  0.001176    0.435271  0.328850
#
#             95_acc_y  max_acc_y
# Unnamed: 0
# 0           1.135934   6.148501
# 1           1.135934   6.148501
# 2           1.205422   6.901017
# 3           1.205422   6.901017
# 4           1.205422   6.901017
#
# [5 rows x 521 columns]

# %%
x = data.iloc[:,1:].values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
d2 = pd.DataFrame(x_scaled)
d2["speed"] = data.iloc[:,0]
train, validate, test = np.split(d2.sample(frac=1), [int(.6*len(d2)), int(.8*len(d2))])

# %%
d2.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.012672  0.010053  0.022331  0.039810  0.067267  0.061797  0.045089
# 1  0.012672  0.010053  0.022331  0.039810  0.067267  0.061797  0.045089
# 2  0.032173  0.059526  0.089143  0.081217  0.142102  0.114948  0.134987
# 3  0.032173  0.059526  0.089143  0.081217  0.142102  0.114948  0.134987
# 4  0.032173  0.059526  0.089143  0.081217  0.142102  0.114948  0.134987
#
#           7         8         9  ...       511       512       513       514  \
# 0  0.056358  0.103751  0.134562  ...  0.063443  0.037567  0.082659  0.053812
# 1  0.056358  0.103751  0.134562  ...  0.063443  0.037567  0.082659  0.053812
# 2  0.062800  0.131163  0.124939  ...  0.043748  0.047197  0.052917  0.039308
# 3  0.062800  0.131163  0.124939  ...  0.043748  0.047197  0.052917  0.039308
# 4  0.062800  0.131163  0.124939  ...  0.043748  0.047197  0.052917  0.039308
#
#         515       516       517       518       519  speed
# 0  0.039585  0.056502  0.060794  0.052717  0.021361   24.0
# 1  0.039585  0.056502  0.060794  0.052717  0.021361   24.0
# 2  0.045075  0.055713  0.056493  0.055965  0.023981   25.0
#        3.43786501e-03, 3.14551915e-03, 3.14778511e-03, 3.07246627e-03,
#        2.83651968e-03, 3.16091803e-03, 2.37099228e-03, 4.25156918e-03,
#        3.45473426e-03, 2.27239354e-03, 2.28189158e-03, 2.45154144e-03,
#        2.06837364e-03, 1.58704473e-03, 2.27253268e-03, 2.05059676e-03,
#        2.49444984e-03, 2.00954384e-03, 2.53478918e-03, 3.58776305e-03,
#        4.17356661e-03, 3.58633484e-03, 2.13569311e-03, 1.43671341e-03,
#        1.97383173e-03, 2.00494564e-03, 2.27909457e-03, 1.55000923e-03,
#        1.26512151e-03, 2.30720873e-03, 1.46810332e-03, 2.43085930e-03,
#        2.27844527e-03, 1.62607915e-03, 2.30725070e-03, 2.09707442e-03,
#        2.21370340e-03, 2.06498539e-03, 1.94696953e-03, 2.00298476e-03,
#        2.01444247e-03, 2.12575367e-03, 2.30115243e-03, 1.65933921e-03,
#        1.51672594e-03, 1.81730407e-03, 1.46853137e-03, 2.69721709e-03,
#        2.41094741e-03, 1.64353151e-03, 1.57139233e-03, 1.40280997e-03,
#        1.44362634e-03, 1.57575791e-03, 1.77047198e-03, 1.37694955e-03,
#        1.24994299e-03, 1.33157721e-03, 1.16909219e-03, 1.27226661e-03,
#        1.27164652e-03, 1.37718441e-03, 1.32899901e-03, 1.06042192e-03,
#        1.51205742e-03, 9.76070468e-04, 1.33623178e-03, 1.09431881e-03,
#        1.35443387e-03, 1.31897748e-03, 1.34209352e-03, 1.67917410e-03,
#        1.00093907e-03, 1.74100165e-03, 1.17312787e-03, 1.03362363e-03,
#        4.41387458e-01, 3.53673012e-01, 1.13593362e+00, 6.14850053e+00])

# %%
y_tr = torch.from_numpy(train.iloc[:,-1].to_numpy())
y_tr = y_tr.view(y_tr.shape[0], 1)
y_te = torch.from_numpy(test.iloc[:,-1].to_numpy())
y_te = y_te.view(y_te.shape[0], 1)
y_va = torch.from_numpy(validate.iloc[:,-1].to_numpy())
y_va = y_va.view(y_va.shape[0], 1)

# %%
x_tr = torch.from_numpy(train.iloc[:,:-1].to_numpy())
x_te = torch.from_numpy(test.iloc[:,:-1].to_numpy())
x_va = torch.from_numpy(validate.iloc[:,:-1].to_numpy())

# %%
print(x_tr.shape, y_tr.shape)
# Out:
# torch.Size([10876, 520]) torch.Size([10876, 1])

# %%
train.head()
# Out:
#               0         1         2         3         4         5         6  \
# 1303   0.007222  0.002119  0.004186  0.007268  0.015572  0.015261  0.012617
# 13836  0.007555  0.012557  0.035053  0.068880  0.083069  0.062110  0.133160
# 4585   0.196153  0.056231  0.126430  0.188457  0.305739  0.250973  0.304457
# 4949   0.014966  0.019306  0.038784  0.063952  0.157339  0.146743  0.173336
# 7796   0.012811  0.029731  0.038069  0.039270  0.048786  0.035549  0.047639
#
#               7         8         9  ...       511       512       513  \
# 1303   0.015505  0.047868  0.059856  ...  0.005565  0.010132  0.016701
# 13836  0.027289  0.024437  0.040646  ...  0.023741  0.019371  0.033566
# 4585   0.256669  0.193487  0.111955  ...  0.249922  0.239861  0.304708
# 4949   0.214538  0.332276  0.224698  ...  0.146199  0.134566  0.151345
#         0.0033, 0.0043, 0.0052, 0.0061, 0.0035, 0.0065, 0.0083, 0.0070, 0.0032,
#         0.0124, 0.0100, 0.0086, 0.0112, 0.0087, 0.0070, 0.0103, 0.0076, 0.0108,
#         0.0107, 0.0067, 0.0066, 0.0070, 0.0052, 0.0062, 0.0066, 0.0073, 0.0092,
#         0.0106, 0.0099, 0.0079, 0.0081, 0.0044, 0.0048, 0.0059, 0.0043, 0.0046,
#         0.0063, 0.0061, 0.0041, 0.0051, 0.0058, 0.0076, 0.0074, 0.0056, 0.0101,
#         0.0167, 0.0115, 0.0087, 0.0127, 0.0140, 0.0116, 0.0025],
#        dtype=torch.float64)

# %%
x_tr = x_tr.float()
y_tr = y_tr.float()
x_tr.shape
# Out:
# torch.Size([10876, 520])

# %%
x3d = x_tr.view(x_tr.shape[0],1,x_tr.shape[1])
x3d.shape
# Out:
# torch.Size([10876, 1, 520])

# %%
x_sq = torch.flatten(x3d, start_dim = 1)
x_sq.shape
# Out:
# torch.Size([10876, 520])

# %%
x_sq[0,-1] == x3d[0,0,-1]
# Out:
# tensor(True)

# %%
x3d[0,0,0:10]
# Out:
# tensor([0.0072, 0.0021, 0.0042, 0.0073, 0.0156, 0.0153, 0.0126, 0.0155, 0.0479,
#         0.0599])

# %%
x_sq[0,0:10]
# Out:
# tensor([0.0072, 0.0021, 0.0042, 0.0073, 0.0156, 0.0153, 0.0126, 0.0155, 0.0479,
#         0.0599])

# %%
m = torch.nn.Conv1d(1,1,5)

# %%
output = m(x3d)
output.shape
# Out:
# torch.Size([10876, 1, 516])

# %%
x_tr = x_tr.cuda()
y_tr = y_tr.cuda()

# %%
x_te = x_te.float().cuda()
y_te = y_te.float().cuda()

# %%
x_va = x_te.float().cuda()
y_va = y_te.float().cuda()

# %%
l_rate = 1e-6

input_dim, hiden_dim, h2, h3, h4, h5, h6, output_dim = 516, 250, 250, 125, 125, 30, 30, y_tr.shape[1]
model = torch.nn.Sequential(
    torch.nn.Conv1d(1,1,5),
    torch.nn.ReLU(),
    torch.nn.Flatten(start_dim =1),
    torch.nn.Linear(input_dim, hiden_dim),
    torch.nn.ReLU(),
    torch.nn.Linear(hiden_dim, h2),
    torch.nn.ReLU(),
    torch.nn.Linear(h2, h3),
    torch.nn.ReLU(),
    torch.nn.Linear(h3, h4),
    torch.nn.ReLU(),
    torch.nn.Linear(h4, h5),
    torch.nn.ReLU(),
    torch.nn.Linear(h5, h6),
    torch.nn.ReLU(),
    torch.nn.Linear(h6, output_dim),
)
model.cuda()
loss_fn = torch.nn.MSELoss(reduction="sum")
losses_train = []
losses_test = []
times = []

# %%
x_tr_3d = x_tr.view(x_tr.shape[0], 1, x_tr.shape[1])
x_te_3d = x_te.view(x_te.shape[0], 1, x_te.shape[1])
x_va_3d = x_va.view(x_va.shape[0], 1, x_va.shape[1])
losses_train = []
losses_test = []
times = []

# %%
# scheduler = optim.X(optimizer,...)      # create lr scheduler
# scheduler.step()                        # update lr at start of epoch
# optim.lr_scheduler.X                    # where X is LambdaLR, StepLR, MultiStepLR,
              # ExponentialLR or ReduceLROnPLateau
learning_rate = 1e-5
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor = 0.2, verbose = True)
for t in range(50000):
    # Forward pass: compute predicted y by passing x to the model.
    y_pred = model(x_tr_3d)

    # Compute and print loss.
    loss = loss_fn(y_pred, y_tr)
    if t % 1000 == 99:
        print("{:16}{:6}  {:5.3f}".format("training error:", t, loss.item()))
        y_test = model(x_te_3d)
        loss_te = loss_fn(y_test, y_te)
        print("{:16}{:6}  {:5.3f}".format("test error:", t, loss_te.item()))
    if t % 100 == 99:
#         print("{:16}{:6}  {:5.3f}".format("training error:", t, loss.item()))
        y_test = model(x_te_3d)
        loss_te = loss_fn(y_test, y_te)
#         print("{:16}{:6}  {:5.3f}".format("test error:", t, loss_te.item()))
        losses_train.append(loss.item())
        losses_test.append(loss_te.item())
        times.append(t)

    # Before the backward pass, use the optimizer object to zero all of the
    # gradients for the variables it will update (which are the learnable
    # weights of the model). This is because by default, gradients are
    # accumulated in buffers( i.e, not overwritten) whenever .backward()
    # is called. Checkout docs of torch.autograd.backward for more details.
    optimizer.zero_grad()

    # Backward pass: compute gradient of the loss with respect to model
    # parameters
    loss.backward()

    # Calling the step function on an Optimizer makes an update to its
    # parameters
    optimizer.step()
#     scheduler.step(loss)
stats = pd.DataFrame({"train_l":losses_train, "test_l":losses_test, "time":times})
# stats.plot(x="time", y=["train_l", "test_l"], kind="scatter")
stats.plot(x="time", y="train_l", kind="scatter")
stats.plot(x="time", y="test_l", kind="scatter")
# Out:
# training error:     99  25904076.000
# test error:         99  8784144.000
# training error:   1099  6258419.500
# test error:       1099  2103155.000
# training error:   2099  5789894.000
# test error:       2099  1935762.375
# training error:   3099  5087607.000
# test error:       3099  1687850.875
# training error:   4099  3900365.000
# test error:       4099  1273381.000
# training error:   5099  2283182.750
# test error:       5099  726497.000
# training error:   6099  1357736.000
# test error:       6099  435693.469
# training error:   7099  893165.250
# test error:       7099  297823.312
# training error:   8099  568343.500
# test error:       8099  193162.906
# training error:   9099  394175.938
# test error:       9099  134161.266
# training error:  10099  312368.656
# test error:      10099  108583.578
# training error:  11099  265175.594
# test error:      11099  94945.039
# training error:  12099  231839.844
# test error:      12099  85488.312
# training error:  13099  204458.656
# test error:      13099  77587.469
# training error:  14099  180673.188
# test error:      14099  70576.703
# training error:  15099  160059.625
# test error:      15099  64395.047
# training error:  16099  142219.203
# test error:      16099  59041.234
# training error:  17099  127322.875
# test error:      17099  54681.203
# training error:  18099  114770.445
# test error:      18099  50984.613
# training error:  19099  104122.062
# test error:      19099  47736.766
# training error:  20099  95109.898
# test error:      20099  44941.648
# training error:  21099  87513.977
# test error:      21099  42388.156
# training error:  22099  81080.031
# test error:      22099  40134.164
# training error:  23099  75524.320
# test error:      23099  38116.281
# training error:  24099  70776.930
# test error:      24099  36359.617
# training error:  25099  66678.352
# test error:      25099  34877.578
# training error:  26099  62895.250
# test error:      26099  33450.090
# training error:  27099  59466.406
# test error:      27099  32167.254
# training error:  28099  56389.789
# test error:      28099  31057.758
# training error:  29099  53613.199
# test error:      29099  30035.324
# training error:  30099  51162.090
# test error:      30099  29165.199
# training error:  31099  48885.070
# test error:      31099  28275.562
# training error:  32099  46839.484
# test error:      32099  27521.203
# training error:  33099  45033.391
# test error:      33099  26832.107
# training error:  34099  43215.691
# test error:      34099  26174.051
# training error:  35099  41642.320
# test error:      35099  25617.039
# training error:  36099  40227.844
# test error:      36099  25106.109
# training error:  37099  38840.367
# test error:      37099  24578.242
# training error:  38099  37617.551
# test error:      38099  24121.191
# training error:  39099  36441.023
# test error:      39099  23713.828
# training error:  40099  35367.566
# test error:      40099  23317.035
# training error:  41099  34404.227
# test error:      41099  22964.250
# training error:  42099  33525.508
# test error:      42099  22642.371
# training error:  43099  32664.213
# test error:      43099  22337.449
# training error:  44099  31886.707
# test error:      44099  22056.996
# training error:  45099  31135.633
# test error:      45099  21790.977
# training error:  46099  30557.957
# test error:      46099  21603.539
# training error:  47099  29788.145
# test error:      47099  21334.764
# training error:  48099  29235.809
# test error:      48099  21134.492
# training error:  49099  28532.703
# test error:      49099  20918.941
# <AxesSubplot:xlabel='time', ylabel='test_l'>

# %%
stats.iloc[5:,:].plot(x="time", y="train_l", kind="scatter")
stats.iloc[5:,:].plot(x="time", y="test_l", kind="scatter")
# Out:
# <AxesSubplot:xlabel='time', ylabel='test_l'>

# %%
stats.iloc[50:,:].plot(x="time", y="train_l", kind="scatter")
stats.iloc[50:,:].plot(x="time", y="test_l", kind="scatter")
# Out:
# <AxesSubplot:xlabel='time', ylabel='test_l'>

# %%
from ray import tune

# %%
# l_rate = 1e-5

# %%
# for t in range(500):
# #     y_pred = model(xc).to(device)
#     y_pred = model(x_tr)
    
# #     y_c_pred = y_pred.to(dev)
#     loss = loss_fn(y_pred, y_tr)
    
#     if t % 1000 == 99:
#         print("{:16}{:6}   {:5.3}".format("training error:", t, loss.item()))
#         y_test = model(x_te)
#         loss_te = loss_fn(y_test, y_te)
#         print("{:16}{:6}  {:5.3}".format("test error:", t, loss_te.item()))
#     if t % 100 == 1:
# #         print("training error:", t, loss.item())
#         y_test = model(x_te)
#         loss_te = loss_fn(y_test, y_te)
# #         print("test error:", t, loss_te.item())
#         losses_train.append(loss.item())
#         losses_test.append(loss_te.item())
#         times.append(t)
#     model.zero_grad()
#     loss.backward()
#     with torch.no_grad():
#         for param in model.parameters():
#             param -= l_rate * param.grad

# %%
# stats = pd.DataFrame({"train_l":losses_train, "test_l":losses_test, "time":times})
# # stats.plot(x="time", y=["train_l", "test_l"], kind="scatter")
# stats.plot(x="time", y="train_l", kind="scatter")
# stats.plot(x="time", y="test_l", kind="scatter")

# %% [markdown]
# to do:
#     Randomize the order of the input data
#     training/test set split
#     optimise architecture
#     test by plotting predicted speeds of other runs
#     investigate 1d convolution layer
#     print the validation set score with loss
#
#     Build alternate model using raw acceleration data (down sample data) - investigate embedding/embedding layer

# %%
# checkpoint = {'input_size': xc.shape[1],
#               'output_size': yc.shape[1],
#               "model_dets": model,
#               'state_dict': model.state_dict()}

# torch.save(checkpoint, 'checkpoint.pth')

# %%
model
# Out:
# Sequential(
#   (0): Conv1d(1, 1, kernel_size=(5,), stride=(1,))
#   (1): ReLU()
#   (2): Flatten()
#   (3): Linear(in_features=516, out_features=250, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=250, out_features=250, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=250, out_features=125, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=125, out_features=125, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=125, out_features=30, bias=True)
#   (12): ReLU()
#   (13): Linear(in_features=30, out_features=30, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=30, out_features=1, bias=True)
# )

# %%
df1 = pd.read_csv("01-08-19-V118_ch1.big" , index_col = 0)
df2 = pd.read_csv("01-08-19-V118_ch2.big" , index_col = 0)

# %%
df1 = df1.reset_index()
df2 = df2.reset_index()

# %%
df = pd.merge(df1, df2, how = "outer", on = "index")
df.head()
# Out:
#    index       0_x      10_x      20_x      30_x      40_x      50_x  \
# 0      0  0.002283  0.001861  0.001776  0.002652  0.004631  0.009036
# 1      1  0.002964  0.002919  0.003401  0.003421  0.005504  0.007987
# 2      2  0.004012  0.003644  0.004012  0.004476  0.006040  0.007929
# 3      3  0.001981  0.002050  0.003021  0.002484  0.004625  0.006709
# 4      4  0.001982  0.001520  0.002056  0.002422  0.006100  0.005771
#
#        60_x      70_x      80_x  ...    2500_y    2510_y    2520_y    2530_y  \
# 0  0.007076  0.006394  0.007697  ...  0.002245  0.001517  0.001681  0.001096
# 1  0.007737  0.006090  0.006359  ...  0.001800  0.001058  0.001129  0.001639
# 2  0.008039  0.007646  0.011035  ...  0.000736  0.001267  0.001046  0.001271
# 3  0.007154  0.006420  0.006462  ...  0.001464  0.001167  0.001430  0.001136
# 4  0.007166  0.006682  0.012416  ...  0.001787  0.001507  0.001729  0.001084
#
#      2540_y    2550_y  mean_acc_y  median_y  95_acc_y  max_acc_y
# 0  0.001384  0.001165    1.198058  0.982748  3.083282   7.179362
# 1  0.001557  0.001575    1.226540  1.033503  3.092825   6.464596
# 2  0.000913  0.001316    1.040367  0.884531  2.612213   5.477276
# 3  0.001324  0.000884    1.173504  1.040558  2.719463   5.129313
# 4  0.001341  0.001238    1.194421  0.971220  3.084037   7.484677
#
# [5 rows x 521 columns]

# %%
x_ch = torch.from_numpy(min_max_scaler.transform(df.iloc[:,1:].values))
x_ch[0,0]
# Out:
# tensor(0.0094, dtype=torch.float64)

# %%
x_ch = x_ch.float()
x_ch[0,0]
# Out:
# tensor(0.0094)

# %%
x_ch = x_ch.to(device)
x_ch[0,0]
# Out:
# tensor(0.0094, device='cuda:0')

# %%
x_ch.device
# Out:
# device(type='cuda', index=0)

# %%
x_ch.shape
# Out:
# torch.Size([7200, 520])

# %%
x_ch_3d = x_ch.view(x_ch.shape[0], 1, x_ch.shape[1])
x_ch_3d.shape
# Out:
# torch.Size([7200, 1, 520])

# %%
y_ch = model(x_ch_3d)

# %%
y_ch.shape
# Out:
# torch.Size([7200, 1])

# %%
ch_np = y_ch.cpu().detach().numpy()
type(ch_np)
# Out:
# numpy.ndarray

# %%
ch_np.shape
# Out:
# (7200, 1)

# %%
df4 = pd.DataFrame(min_max_scaler.fit_transform(df.iloc[:,1:].values))

# %%
df4["speed"] = ch_np

# %%
df4.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.020097  0.022020  0.018606  0.019429  0.039860  0.087220  0.052739
# 1  0.027849  0.035832  0.036919  0.025260  0.047492  0.076990  0.057707
# 2  0.039784  0.045306  0.043794  0.033255  0.052173  0.076431  0.059969
# 3  0.016658  0.024483  0.032631  0.018159  0.039809  0.064532  0.053328
# 4  0.016668  0.017564  0.021759  0.017689  0.052701  0.055381  0.053413
#
#           7         8         9  ...       511       512       513       514  \
# 0  0.033737  0.033995  0.111145  ...  0.077909  0.057966  0.041450  0.039170
# 1  0.032120  0.028055  0.068393  ...  0.054174  0.038812  0.062178  0.044094
# 2  0.040399  0.048814  0.104750  ...  0.064978  0.035921  0.048134  0.025770
# 3  0.033877  0.028515  0.093867  ...  0.059833  0.049262  0.042966  0.037461
# 4  0.035270  0.054942  0.120275  ...  0.077393  0.059597  0.040976  0.037936
#
#         515       516       517       518       519      speed
# 0  0.032053  0.151787  0.159889  0.130344  0.043584  21.379578
# 1  0.043426  0.155407  0.168173  0.130748  0.039235  25.647089
# 2  0.036261  0.131745  0.143859  0.110371  0.033227  19.773275
# 3  0.024272  0.148666  0.169324  0.114918  0.031110  21.069374
# 4  0.034089  0.151325  0.158007  0.130376  0.045442  22.610767
#
# [5 rows x 521 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-7bda610047e0> in <module>
# ----> 1 df5 = min_max_scaler.inverse_transform(df4.values)
#
# C:\ProgramData\Anaconda3\envs\PyTorch_37\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X)
#     430                         force_all_finite="allow-nan")
#     431
# --> 432         X -= self.min_
#     433         X /= self.scale_
#     434         return X
#
# ValueError: operands could not be broadcast together with shapes (7200,521) (520,) (7200,521)

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
df4.plot("speed")
# Out:
# <AxesSubplot:xlabel='speed'>

# %%
plotdf = df4.reset_index()

# %%
plotdf.head()
# Out:
#    index         0         1         2         3         4         5  \
# 0      0  0.020097  0.022020  0.018606  0.019429  0.039860  0.087220
# 1      1  0.027849  0.035832  0.036919  0.025260  0.047492  0.076990
# 2      2  0.039784  0.045306  0.043794  0.033255  0.052173  0.076431
# 3      3  0.016658  0.024483  0.032631  0.018159  0.039809  0.064532
# 4      4  0.016668  0.017564  0.021759  0.017689  0.052701  0.055381
#
#           6         7         8  ...       511       512       513       514  \
# 0  0.052739  0.033737  0.033995  ...  0.077909  0.057966  0.041450  0.039170
# 1  0.057707  0.032120  0.028055  ...  0.054174  0.038812  0.062178  0.044094
# 2  0.059969  0.040399  0.048814  ...  0.064978  0.035921  0.048134  0.025770
# 3  0.053328  0.033877  0.028515  ...  0.059833  0.049262  0.042966  0.037461
# 4  0.053413  0.035270  0.054942  ...  0.077393  0.059597  0.040976  0.037936
#
#         515       516       517       518       519      speed
# 0  0.032053  0.151787  0.159889  0.130344  0.043584  21.379578
# 1  0.043426  0.155407  0.168173  0.130748  0.039235  25.647089
# 2  0.036261  0.131745  0.143859  0.110371  0.033227  19.773275
# 3  0.024272  0.148666  0.169324  0.114918  0.031110  21.069374
# 4  0.034089  0.151325  0.158007  0.130376  0.045442  22.610767
#
# [5 rows x 522 columns]

# %%
plt.figure(figsize= (30, 30))
g = sb.scatterplot(x = "index", y = "speed", data = plotdf, alpha = 0.2, color ="b")
g = sb.scatterplot(x = "index", y = data.iloc[:,-2], data = plotdf, alpha = 0.2, color ="r")

# %%
plt.figure(figsize= (30, 30))
sb.lineplot(x = "index", y = "speed", data = plotdf.iloc[0:1000,:], color ="b")
# sb.lineplot(x = "index", y = "speed", data = plotdf.iloc[0:1000,:], alpha = 0.2, color ="b")
# Out:
# <AxesSubplot:xlabel='index', ylabel='speed'>
